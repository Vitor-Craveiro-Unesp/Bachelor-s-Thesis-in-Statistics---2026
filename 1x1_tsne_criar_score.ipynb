# %%
# ============================================================
# GRID t-SNE 1D + GMM OTIMIZADO
# CSV RESUMO: UMA LINHA POR PERPLEXIDADE
# SAÍDA FIXA: 1x1_tsne_score.csv
# GRADE DE PERPLEXIDADE: GEOMÉTRICA / LOGARÍTMICA
# COM RANKING, PARALELISMO E max_iter = 250
# ============================================================

import time
import inspect
import warnings
import numpy as np
import pandas as pd

from pathlib import Path

from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.mixture import GaussianMixture

from sklearn.metrics import (
    average_precision_score,
    precision_recall_curve,
    log_loss
)

warnings.filterwarnings("ignore")


# ============================================================
# BARRA DE PROGRESSO
# ============================================================

try:
    from tqdm.notebook import tqdm
except Exception:
    from tqdm import tqdm


# ============================================================
# FUNÇÕES AUXILIARES
# ============================================================

def detectar_target(df):
    if "status_fraude" in df.columns:
        return "status_fraude"

    if "Class" in df.columns:
        return "Class"

    raise ValueError("Não encontrei a coluna target: 'status_fraude' ou 'Class'.")


def criar_tsne_compat(
    perplexity,
    random_state=42,
    init="pca",
    max_iter=250,
    learning_rate="auto",
    n_jobs=-1,
    verbose=0,
    method="barnes_hut",
    angle=0.5
):
    """
    Cria TSNE 1D compatível com versões diferentes do sklearn.
    Algumas versões usam max_iter; outras usam n_iter.
    """

    assinatura = inspect.signature(TSNE)
    parametros = assinatura.parameters

    kwargs = {
        "n_components": 1,
        "perplexity": perplexity,
        "random_state": random_state,
        "init": init,
        "learning_rate": learning_rate,
        "method": method,
        "angle": angle,
        "verbose": verbose
    }

    if "max_iter" in parametros:
        kwargs["max_iter"] = max_iter
    else:
        kwargs["n_iter"] = max_iter

    if "n_jobs" in parametros:
        kwargs["n_jobs"] = n_jobs

    return TSNE(**kwargs)


def formatar_tempo(segundos):
    segundos = int(segundos)

    h = segundos // 3600
    m = (segundos % 3600) // 60
    s = segundos % 60

    if h > 0:
        return f"{h}h {m}min {s}s"

    if m > 0:
        return f"{m}min {s}s"

    return f"{s}s"


def calcular_mcc_vetorizado(tp, fp, fn, tn):
    """
    Calcula MCC de forma vetorizada.
    """

    numerador = (tp * tn) - (fp * fn)

    denominador = np.sqrt(
        (tp + fp) *
        (tp + fn) *
        (tn + fp) *
        (tn + fn)
    )

    mcc = np.divide(
        numerador,
        denominador,
        out=np.zeros_like(numerador, dtype=float),
        where=denominador != 0
    )

    return mcc


def encontrar_melhor_corte_mcc(y_true, prob_fraude):
    """
    Encontra o melhor ponto de corte maximizando MCC.
    Versão vetorizada e rápida.
    """

    y_true = np.asarray(y_true).astype(int)
    prob_fraude = np.asarray(prob_fraude, dtype=float)

    precision, recall, thresholds = precision_recall_curve(
        y_true,
        prob_fraude
    )

    if len(thresholds) == 0:
        return 0.5, 0.0

    precision = precision[:-1]
    recall = recall[:-1]

    total_pos = np.sum(y_true == 1)
    total_neg = np.sum(y_true == 0)

    tp = recall * total_pos

    fp = np.zeros_like(tp, dtype=float)

    mask_precision = precision > 0

    fp[mask_precision] = tp[mask_precision] * (
        (1.0 / precision[mask_precision]) - 1.0
    )

    fn = total_pos - tp
    tn = total_neg - fp

    mccs = calcular_mcc_vetorizado(
        tp=tp,
        fp=fp,
        fn=fn,
        tn=tn
    )

    melhor_idx = int(np.nanargmax(mccs))

    melhor_corte = thresholds[melhor_idx]
    melhor_mcc = mccs[melhor_idx]

    return float(melhor_corte), float(melhor_mcc)


def calcular_log_veross_gmm(gmm, X):
    """
    Log-verossimilhança total da GMM.
    """

    log_prob = gmm.score_samples(X)

    return float(np.sum(log_prob))


def calcular_neg_log_veross_com_rotulo(prob_fraude, y_true):
    """
    Negative log-likelihood usando o rótulo real.

    Se y = 1, usa P(fraude).
    Se y = 0, usa 1 - P(fraude).
    """

    eps = 1e-15

    prob_fraude = np.clip(
        prob_fraude,
        eps,
        1 - eps
    )

    y_true = np.asarray(y_true).astype(int)

    log_veross = (
        y_true * np.log(prob_fraude)
        + (1 - y_true) * np.log(1 - prob_fraude)
    )

    return float(-np.sum(log_veross))


def calcular_log_loss_norm(log_loss_valor):
    """
    Normalização simples do log loss.
    Quanto menor o log loss, mais próximo de 1.
    """

    log_loss_norm = 1 / (1 + log_loss_valor)

    log_loss_norm = np.clip(
        log_loss_norm,
        0,
        1
    )

    return float(log_loss_norm)


def gerar_score_final(auc_pr, mcc, log_loss_norm):
    """
    Score final usando:
    - AUC-PR
    - MCC
    - Log Loss normalizado

    Pesos usados:
    AUC-PR: 0.45
    MCC: 0.40
    Log Loss normalizado: 0.15
    """

    score = (
        0.45 * auc_pr
        + 0.40 * max(mcc, 0)
        + 0.15 * log_loss_norm
    )

    return float(score)


def gerar_perplexidades_geometricas(
    perplexity_inicio=5,
    perplexity_fim=300,
    perplexity_num=15
):
    """
    Gera uma grade aproximadamente logarítmica/geométrica
    de perplexidades.

    Exemplo:
    início=5, fim=300, num=15

    Saída aproximada:
    [5, 7, 9, 12, 16, 22, 29, 39, 52, 70, 94, 126, 169, 225, 300]
    """

    if perplexity_num <= 1:
        raise ValueError("perplexity_num precisa ser maior que 1.")

    if perplexity_inicio <= 0:
        raise ValueError("perplexity_inicio precisa ser maior que zero.")

    if perplexity_fim <= perplexity_inicio:
        raise ValueError("perplexity_fim precisa ser maior que perplexity_inicio.")

    perplexidades = np.geomspace(
        perplexity_inicio,
        perplexity_fim,
        num=perplexity_num
    )

    perplexidades = np.round(perplexidades).astype(int)
    perplexidades = np.unique(perplexidades).tolist()

    return perplexidades


# ============================================================
# FUNÇÃO PRINCIPAL DO GRID
# ============================================================

def gerar_grid_tsne_1d_scores_resumo(
    arquivo_dados="creditcard.csv",
    arquivo_saida="1x1_tsne_score.csv",
    pasta_saida=".",
    perplexidades=(30, 50),
    random_state=42,
    init="pca",
    max_iter=250,
    learning_rate="auto",
    n_jobs_tsne=-1,
    features_tsne=None,
    target_name=None,
    gmm_n_components=2,
    gmm_n_init=3,
    gmm_random_state=42,
    gmm_covariance_type="full",
    reg_covar=1e-6,
    escalar_antes_tsne=True,
    escalar_tsne_para_gmm=True,
    verbose_tsne=0,
    method_tsne="barnes_hut",
    angle_tsne=0.5,
    salvar_parcial=True,
    arquivo_parcial="1x1_tsne_score_parcial.csv"
):

    tempo_inicio_total = time.time()

    pasta_saida = Path(pasta_saida)
    pasta_saida.mkdir(parents=True, exist_ok=True)

    caminho_saida = pasta_saida / arquivo_saida
    caminho_parcial = pasta_saida / arquivo_parcial

    # ========================================================
    # LEITURA
    # ========================================================

    df = pd.read_csv(arquivo_dados)

    if target_name is None:
        target_name = detectar_target(df)

    if target_name not in df.columns:
        raise ValueError(f"Target '{target_name}' não encontrado no arquivo.")

    # ========================================================
    # FEATURES DE ENTRADA DO t-SNE
    # ========================================================

    if features_tsne is None:
        features_tsne = [
            col for col in df.columns
            if col != target_name and pd.api.types.is_numeric_dtype(df[col])
        ]

    if len(features_tsne) == 0:
        raise ValueError("Nenhuma feature numérica encontrada para o t-SNE.")

    dados = df[
        features_tsne + [target_name]
    ].dropna().copy()

    X_original = dados[features_tsne].copy()
    y = dados[target_name].astype(int).to_numpy()

    valores_target = sorted(np.unique(y))

    if set(valores_target) != {0, 1}:
        raise ValueError(
            f"O target precisa ser binário com valores 0 e 1. "
            f"Valores encontrados: {valores_target}"
        )

    n_amostras = X_original.shape[0]

    perplexidades = list(perplexidades)

    perplexidades_validas = [
        p for p in perplexidades
        if p < n_amostras
    ]

    if len(perplexidades_validas) == 0:
        raise ValueError(
            "Nenhuma perplexidade válida. "
            "A perplexidade precisa ser menor que o número de amostras."
        )

    scaler_antes_tsne_nome = "StandardScaler" if escalar_antes_tsne else "None"
    scaler_tsne_para_gmm_nome = "StandardScaler" if escalar_tsne_para_gmm else "None"

    print("=" * 80)
    print("GRID t-SNE 1D + GMM - CSV RESUMO COM REPLICAÇÃO")
    print("=" * 80)
    print(f"Arquivo: {arquivo_dados}")
    print(f"CSV final: {arquivo_saida}")
    print(f"CSV parcial: {arquivo_parcial}")
    print(f"Target: {target_name}")
    print(f"Amostras usadas: {n_amostras:,}".replace(",", "."))
    print(f"Features usadas no t-SNE: {len(features_tsne)}")
    print(f"Perplexidades válidas: {perplexidades_validas}")
    print(f"n_components t-SNE: 1")
    print(f"max_iter: {max_iter}")
    print(f"init: {init}")
    print(f"learning_rate: {learning_rate}")
    print(f"random_state t-SNE: {random_state}")
    print(f"n_jobs_tsne: {n_jobs_tsne}")
    print(f"method_tsne: {method_tsne}")
    print(f"angle_tsne: {angle_tsne}")
    print(f"scaler antes t-SNE: {scaler_antes_tsne_nome}")
    print(f"scaler t-SNE para GMM: {scaler_tsne_para_gmm_nome}")
    print(f"GMM random_state: {gmm_random_state}")
    print("=" * 80)

    # ========================================================
    # ESCALONAMENTO ANTES DO t-SNE
    # ========================================================

    if escalar_antes_tsne:
        scaler_features = StandardScaler()
        X_tsne_input = scaler_features.fit_transform(X_original)
    else:
        X_tsne_input = X_original.to_numpy()

    resultados = []

    barra = tqdm(
        perplexidades_validas,
        desc="Grid t-SNE 1D",
        unit="perplexidade",
        leave=True
    )

    # ========================================================
    # LOOP DAS PERPLEXIDADES
    # ========================================================

    for idx, perplexity in enumerate(barra, start=1):

        tempo_inicio = time.time()

        barra.set_postfix(
            {
                "perplexity": perplexity,
                "status": "t-SNE 1D"
            }
        )

        print()
        print("-" * 80)
        print(f"[{idx}/{len(perplexidades_validas)}] Rodando t-SNE 1D | perplexity={perplexity}")
        print("-" * 80)

        # ====================================================
        # t-SNE 1D
        # ====================================================

        tsne = criar_tsne_compat(
            perplexity=perplexity,
            random_state=random_state,
            init=init,
            max_iter=max_iter,
            learning_rate=learning_rate,
            n_jobs=n_jobs_tsne,
            verbose=verbose_tsne,
            method=method_tsne,
            angle=angle_tsne
        )

        X_tsne = tsne.fit_transform(X_tsne_input)

        n_iter_real = getattr(tsne, "n_iter_", np.nan)

        # Garantir formato 2D para GMM: (n_amostras, 1)
        X_tsne = np.asarray(X_tsne).reshape(-1, 1)

        barra.set_postfix(
            {
                "perplexity": perplexity,
                "status": "GMM"
            }
        )

        # ====================================================
        # ESCALONAMENTO DO t-SNE 1D PARA GMM
        # ====================================================

        if escalar_tsne_para_gmm:
            scaler_gmm = StandardScaler()
            X_gmm = scaler_gmm.fit_transform(X_tsne)
        else:
            X_gmm = X_tsne

        # ====================================================
        # GMM NO ESPAÇO 1D DO t-SNE
        # ====================================================

        gmm = GaussianMixture(
            n_components=gmm_n_components,
            covariance_type=gmm_covariance_type,
            random_state=gmm_random_state,
            n_init=gmm_n_init,
            reg_covar=reg_covar
        )

        gmm.fit(X_gmm)

        clusters = gmm.predict(X_gmm)
        responsabilidades = gmm.predict_proba(X_gmm)

        tabela_cluster = pd.crosstab(
            clusters,
            y
        )

        if 1 not in tabela_cluster.columns:
            raise ValueError("A classe fraude, valor 1, não foi encontrada no target.")

        cluster_fraude = int(tabela_cluster[1].idxmax())

        prob_fraude = responsabilidades[:, cluster_fraude]

        prob_fraude = np.clip(
            prob_fraude,
            1e-15,
            1 - 1e-15
        )

        # ====================================================
        # MÉTRICAS
        # ====================================================

        auc_pr = average_precision_score(
            y,
            prob_fraude
        )

        log_loss_valor = log_loss(
            y,
            prob_fraude,
            labels=[0, 1]
        )

        log_loss_norm = calcular_log_loss_norm(
            log_loss_valor
        )

        melhor_ponto_corte, mcc = encontrar_melhor_corte_mcc(
            y_true=y,
            prob_fraude=prob_fraude
        )

        ponto_corte_medio = 0.5

        log_veross_gmm = calcular_log_veross_gmm(
            gmm=gmm,
            X=X_gmm
        )

        neg_log_veross_gmm = -log_veross_gmm

        neg_log_veross_com_rotulo = calcular_neg_log_veross_com_rotulo(
            prob_fraude=prob_fraude,
            y_true=y
        )

        diferenca_neg_log_veross = (
            neg_log_veross_com_rotulo
            - neg_log_veross_gmm
        )

        score_final = gerar_score_final(
            auc_pr=auc_pr,
            mcc=mcc,
            log_loss_norm=log_loss_norm
        )

        tempo_execucao = time.time() - tempo_inicio
        tempo_formatado = formatar_tempo(tempo_execucao)

        # ====================================================
        # RESULTADO
        # ====================================================

        resultado = {
            "Perplexity": int(perplexity),
            "N_Components_TSNE": 1,
            "Max_Iter": int(max_iter),
            "N_Iter_Real": n_iter_real,
            "Init": init,
            "Learning_Rate": learning_rate,
            "Random_State_TSNE": random_state,
            "Method_TSNE": method_tsne,
            "Angle_TSNE": float(angle_tsne),
            "N_Jobs_TSNE": n_jobs_tsne,
            "Scaler_Antes_TSNE": scaler_antes_tsne_nome,
            "Scaler_TSNE_Para_GMM": scaler_tsne_para_gmm_nome,

            "GMM_N_Components": int(gmm_n_components),
            "GMM_Covariance_Type": gmm_covariance_type,
            "GMM_N_Init": int(gmm_n_init),
            "GMM_Random_State": gmm_random_state,
            "GMM_Reg_Covar": float(reg_covar),

            "AUC_PR": float(auc_pr),
            "MCC": float(mcc),
            "Log_Loss": float(log_loss_valor),
            "Log_Loss_Norm": float(log_loss_norm),

            "Neg_Log_Veross_Com_Rotulo": float(neg_log_veross_com_rotulo),
            "Neg_Log_Veross_GMM": float(neg_log_veross_gmm),
            "Diferenca_Neg_Log_Veross": float(diferenca_neg_log_veross),

            "Score_Final": float(score_final),
            "Melhor_Ponto_Corte": float(melhor_ponto_corte),
            "Ponto_Corte_Medio": float(ponto_corte_medio),

            "Tempo": tempo_formatado
        }

        resultados.append(resultado)

        # ====================================================
        # SALVAR PARCIAL COM RANKING
        # ====================================================

        df_parcial = pd.DataFrame(resultados)

        df_parcial = df_parcial.sort_values(
            by="Score_Final",
            ascending=False
        ).reset_index(drop=True)

        df_parcial["Posicao_Rank"] = np.arange(
            1,
            len(df_parcial) + 1
        )

        if salvar_parcial:
            df_parcial.to_csv(
                caminho_parcial,
                index=False
            )

        barra.set_postfix(
            {
                "perplexity": perplexity,
                "score": f"{score_final:.4f}",
                "tempo": tempo_formatado
            }
        )

        print(f"Perplexity: {perplexity}")
        print(f"AUC-PR: {auc_pr:.6f}")
        print(f"MCC: {mcc:.6f}")
        print(f"Log Loss: {log_loss_valor:.6f}")
        print(f"Log Loss Norm: {log_loss_norm:.6f}")
        print(f"Score Final: {score_final:.6f}")
        print(f"Melhor ponto de corte: {melhor_ponto_corte:.6f}")
        print(f"Tempo: {tempo_formatado}")

        if salvar_parcial:
            print(f"Parcial salvo em: {caminho_parcial.resolve()}")

    # ========================================================
    # CSV FINAL COM RANKING
    # ========================================================

    df_resultados = pd.DataFrame(resultados)

    df_resultados = df_resultados.sort_values(
        by="Score_Final",
        ascending=False
    ).reset_index(drop=True)

    df_resultados["Posicao_Rank"] = np.arange(
        1,
        len(df_resultados) + 1
    )

    colunas_ordenadas = [
        "Posicao_Rank",

        "Perplexity",
        "N_Components_TSNE",
        "Max_Iter",
        "N_Iter_Real",
        "Init",
        "Learning_Rate",
        "Random_State_TSNE",
        "Method_TSNE",
        "Angle_TSNE",
        "N_Jobs_TSNE",
        "Scaler_Antes_TSNE",
        "Scaler_TSNE_Para_GMM",

        "GMM_N_Components",
        "GMM_Covariance_Type",
        "GMM_N_Init",
        "GMM_Random_State",
        "GMM_Reg_Covar",

        "AUC_PR",
        "MCC",
        "Log_Loss",
        "Log_Loss_Norm",

        "Neg_Log_Veross_Com_Rotulo",
        "Neg_Log_Veross_GMM",
        "Diferenca_Neg_Log_Veross",

        "Score_Final",
        "Melhor_Ponto_Corte",
        "Ponto_Corte_Medio",

        "Tempo"
    ]

    df_resultados = df_resultados[colunas_ordenadas]

    df_resultados.to_csv(
        caminho_saida,
        index=False
    )

    tempo_total = time.time() - tempo_inicio_total

    print()
    print("=" * 80)
    print("GRID FINALIZADO")
    print("=" * 80)
    print(f"CSV resumo salvo em: {caminho_saida.resolve()}")
    print(f"Linhas no CSV final: {len(df_resultados)}")
    print(f"Colunas no CSV final: {len(df_resultados.columns)}")
    print(f"Tempo total: {formatar_tempo(tempo_total)}")
    print("=" * 80)

    return df_resultados


# ============================================================
# FUNÇÃO PERSONALIZADA COM GRADE LOGARÍTMICA
# ============================================================

def rodar_grid_tsne_1d_personalizado(
    perplexity_inicio=5,
    perplexity_fim=300,
    perplexity_num=15,
    arquivo_dados="creditcard.csv",
    pasta_saida=".",
    arquivo_saida="1x1_tsne_score.csv",
    random_state=42,
    init="pca",
    max_iter=250,
    learning_rate="auto",
    n_jobs_tsne=-1,
    target_name=None,
    verbose_tsne=0,
    method_tsne="barnes_hut",
    angle_tsne=0.5,
    gmm_n_components=2,
    gmm_n_init=3,
    gmm_random_state=42,
    gmm_covariance_type="full",
    reg_covar=1e-6,
    escalar_antes_tsne=True,
    escalar_tsne_para_gmm=True
):

    perplexidades = gerar_perplexidades_geometricas(
        perplexity_inicio=perplexity_inicio,
        perplexity_fim=perplexity_fim,
        perplexity_num=perplexity_num
    )

    arquivo_parcial = arquivo_saida.replace(
        ".csv",
        "_parcial.csv"
    )

    print("=" * 80)
    print("GRID t-SNE 1D PERSONALIZADO - GRADE LOGARÍTMICA")
    print("=" * 80)
    print(f"Perplexity início: {perplexity_inicio}")
    print(f"Perplexity fim: {perplexity_fim}")
    print(f"Quantidade de valores: {perplexity_num}")
    print(f"Perplexidades geradas: {perplexidades}")
    print(f"Arquivo final: {arquivo_saida}")
    print(f"Arquivo parcial: {arquivo_parcial}")
    print(f"max_iter: {max_iter}")
    print(f"n_jobs_tsne: {n_jobs_tsne}")
    print("=" * 80)

    return gerar_grid_tsne_1d_scores_resumo(
        arquivo_dados=arquivo_dados,
        arquivo_saida=arquivo_saida,
        pasta_saida=pasta_saida,
        perplexidades=perplexidades,
        random_state=random_state,
        init=init,
        max_iter=max_iter,
        learning_rate=learning_rate,
        n_jobs_tsne=n_jobs_tsne,
        target_name=target_name,
        verbose_tsne=verbose_tsne,
        method_tsne=method_tsne,
        angle_tsne=angle_tsne,
        gmm_n_components=gmm_n_components,
        gmm_n_init=gmm_n_init,
        gmm_random_state=gmm_random_state,
        gmm_covariance_type=gmm_covariance_type,
        reg_covar=reg_covar,
        escalar_antes_tsne=escalar_antes_tsne,
        escalar_tsne_para_gmm=escalar_tsne_para_gmm,
        salvar_parcial=True,
        arquivo_parcial=arquivo_parcial
    )


# ============================================================
# EXECUÇÃO
# ============================================================

df_grid_1d = rodar_grid_tsne_1d_personalizado(
    perplexity_inicio=5,
    perplexity_fim=300,
    perplexity_num=15,
    arquivo_dados="creditcard.csv",
    pasta_saida=".",
    arquivo_saida="1x1_tsne_score.csv",
    max_iter=250,
    n_jobs_tsne=-1,
    init="pca",
    learning_rate="auto",
    random_state=42,
    gmm_random_state=42,
    target_name=None,
    verbose_tsne=0
)

df_grid_1d.head()
# Out:
# ================================================================================
# GRID t-SNE 1D PERSONALIZADO - GRADE LOGARÍTMICA
# ================================================================================
# Perplexity início: 5
# Perplexity fim: 300
# Quantidade de valores: 15
# Perplexidades geradas: [5, 7, 9, 12, 16, 22, 29, 39, 52, 70, 93, 125, 167, 224, 300]
# Arquivo final: 1x1_tsne_score.csv
# Arquivo parcial: 1x1_tsne_score_parcial.csv
# ================================================================================
# ================================================================================
# GRID t-SNE 1D + GMM - CSV RESUMO COM REPLICAÇÃO
# ================================================================================
# Arquivo: creditcard.csv
# CSV final: 1x1_tsne_score.csv
# CSV parcial: 1x1_tsne_score_parcial.csv
# Target: status_fraude
# Amostras usadas: 283.726
# Features usadas no t-SNE: 30
# Perplexidades válidas: [5, 7, 9, 12, 16, 22, 29, 39, 52, 70, 93, 125, 167, 224, 300]
# n_components t-SNE: 1
# max_iter: 300
# init: pca
# learning_rate: auto
# random_state t-SNE: 42
# n_jobs_tsne: -1
# method_tsne: barnes_hut
# angle_tsne: 0.5
# scaler antes t-SNE: StandardScaler
# scaler t-SNE para GMM: StandardScaler
# GMM random_state: 42
# ================================================================================
# Grid t-SNE 1D:   0%|          | 0/15 [00:00<?, ?perplexidade/s]
# --------------------------------------------------------------------------------
# [1/15] Rodando t-SNE 1D | perplexity=5
# --------------------------------------------------------------------------------
# Perplexity: 5
# AUC-PR: 0.007785
# MCC: 0.066540
# Log Loss: 1.713998
# Log Loss Norm: 0.368460
# Score Final: 0.085388
# Melhor ponto de corte: 0.983961
# Tempo: 8min 21s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [2/15] Rodando t-SNE 1D | perplexity=7
# --------------------------------------------------------------------------------
# Perplexity: 7
# AUC-PR: 0.120973
# MCC: 0.366157
# Log Loss: 1.702423
# Log Loss Norm: 0.370038
# Score Final: 0.256407
# Melhor ponto de corte: 0.999619
# Tempo: 8min 17s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [3/15] Rodando t-SNE 1D | perplexity=9
# --------------------------------------------------------------------------------
# Perplexity: 9
# AUC-PR: 0.147479
# MCC: 0.384754
# Log Loss: 1.699844
# Log Loss Norm: 0.370392
# Score Final: 0.275826
# Melhor ponto de corte: 0.999628
# Tempo: 8min 27s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [4/15] Rodando t-SNE 1D | perplexity=12
# --------------------------------------------------------------------------------
# Perplexity: 12
# AUC-PR: 0.150805
# MCC: 0.402600
# Log Loss: 1.732678
# Log Loss Norm: 0.365941
# Score Final: 0.283794
# Melhor ponto de corte: 0.999674
# Tempo: 8min 42s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [5/15] Rodando t-SNE 1D | perplexity=16
# --------------------------------------------------------------------------------
# Perplexity: 16
# AUC-PR: 0.155990
# MCC: 0.402600
# Log Loss: 1.669223
# Log Loss Norm: 0.374641
# Score Final: 0.287432
# Melhor ponto de corte: 0.999581
# Tempo: 8min 58s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [6/15] Rodando t-SNE 1D | perplexity=22
# --------------------------------------------------------------------------------
# Perplexity: 22
# AUC-PR: 0.158813
# MCC: 0.402600
# Log Loss: 1.646930
# Log Loss Norm: 0.377796
# Score Final: 0.289176
# Melhor ponto de corte: 0.999532
# Tempo: 9min 19s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [7/15] Rodando t-SNE 1D | perplexity=29
# --------------------------------------------------------------------------------
# Perplexity: 29
# AUC-PR: 0.002918
# MCC: 0.056234
# Log Loss: 1.641980
# Log Loss Norm: 0.378504
# Score Final: 0.080583
# Melhor ponto de corte: 0.961351
# Tempo: 10min 9s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [8/15] Rodando t-SNE 1D | perplexity=39
# --------------------------------------------------------------------------------
# Perplexity: 39
# AUC-PR: 0.002608
# MCC: 0.050486
# Log Loss: 1.635346
# Log Loss Norm: 0.379457
# Score Final: 0.078287
# Melhor ponto de corte: 0.938421
# Tempo: 10min 37s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [9/15] Rodando t-SNE 1D | perplexity=52
# --------------------------------------------------------------------------------
# Perplexity: 52
# AUC-PR: 0.002655
# MCC: 0.049987
# Log Loss: 1.610046
# Log Loss Norm: 0.383135
# Score Final: 0.078660
# Melhor ponto de corte: 0.936373
# Tempo: 11min 35s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [10/15] Rodando t-SNE 1D | perplexity=70
# --------------------------------------------------------------------------------
# Perplexity: 70
# AUC-PR: 0.002260
# MCC: 0.041830
# Log Loss: 1.611360
# Log Loss Norm: 0.382942
# Score Final: 0.075190
# Melhor ponto de corte: 0.876562
# Tempo: 12min 57s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [11/15] Rodando t-SNE 1D | perplexity=93
# --------------------------------------------------------------------------------
# Perplexity: 93
# AUC-PR: 0.002258
# MCC: 0.041175
# Log Loss: 1.585746
# Log Loss Norm: 0.386736
# Score Final: 0.075497
# Melhor ponto de corte: 0.868289
# Tempo: 14min 45s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [12/15] Rodando t-SNE 1D | perplexity=125
# --------------------------------------------------------------------------------
# Perplexity: 125
# AUC-PR: 0.003744
# MCC: 0.066865
# Log Loss: 1.944453
# Log Loss Norm: 0.339622
# Score Final: 0.079374
# Melhor ponto de corte: 0.985138
# Tempo: 18min 26s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [13/15] Rodando t-SNE 1D | perplexity=167
# --------------------------------------------------------------------------------
# Perplexity: 167
# AUC-PR: 0.003037
# MCC: 0.058071
# Log Loss: 1.801987
# Log Loss Norm: 0.356890
# Score Final: 0.078129
# Melhor ponto de corte: 0.955424
# Tempo: 24min 40s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [14/15] Rodando t-SNE 1D | perplexity=224
# --------------------------------------------------------------------------------
# Perplexity: 224
# AUC-PR: 0.002775
# MCC: 0.054309
# Log Loss: 1.730886
# Log Loss Norm: 0.366182
# Score Final: 0.077899
# Melhor ponto de corte: 0.932298
# Tempo: 1h 55min 7s
# Parcial salvo em: C:\Users\Vitor Craveiro\Desktop\UNESP\MATÉRIAS FACULDADES\MATÉRIAS 12 SEMESTRES\TRABALHO DE CONCLUSAO DE CURSO 2\1x1_tsne_score_parcial.csv
#
# --------------------------------------------------------------------------------
# [15/15] Rodando t-SNE 1D | perplexity=300
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 803
#     773     return gerar_grid_tsne_1d_scores_resumo(
#     774         arquivo_dados=arquivo_dados,
#     775         arquivo_saida=arquivo_saida,
#    (...)    795         arquivo_parcial=arquivo_parcial
#     796     )
#     799 # ============================================================
#     800 # EXECUÇÃO
#     801 # ============================================================
# --> 803 df_grid_1d = rodar_grid_tsne_1d_personalizado(
#     804     perplexity_inicio=5,
#     805     perplexity_fim=300,
#     806     perplexity_num=15,
#     807     arquivo_dados="creditcard.csv",
#     808     pasta_saida=".",
#     809     arquivo_saida="1x1_tsne_score.csv",
#     810     max_iter=300,
#     811     n_jobs_tsne=-1,
#     812     init="pca",
#     813     learning_rate="auto",
#     814     random_state=42,
#     815     gmm_random_state=42,
#     816     target_name=None,
#     817     verbose_tsne=0
#     818 )
#     820 df_grid_1d.head()
#
# Cell In[3], line 773, in rodar_grid_tsne_1d_personalizado(perplexity_inicio, perplexity_fim, perplexity_num, arquivo_dados, pasta_saida, arquivo_saida, random_state, init, max_iter, learning_rate, n_jobs_tsne, target_name, verbose_tsne, method_tsne, angle_tsne, gmm_n_components, gmm_n_init, gmm_random_state, gmm_covariance_type, reg_covar, escalar_antes_tsne, escalar_tsne_para_gmm)
#     770 print(f"Arquivo parcial: {arquivo_parcial}")
#     771 print("=" * 80)
# --> 773 return gerar_grid_tsne_1d_scores_resumo(
#     774     arquivo_dados=arquivo_dados,
#     775     arquivo_saida=arquivo_saida,
#     776     pasta_saida=pasta_saida,
#     777     perplexidades=perplexidades,
#     778     random_state=random_state,
#     779     init=init,
#     780     max_iter=max_iter,
#     781     learning_rate=learning_rate,
#     782     n_jobs_tsne=n_jobs_tsne,
#     783     target_name=target_name,
#     784     verbose_tsne=verbose_tsne,
#     785     method_tsne=method_tsne,
#     786     angle_tsne=angle_tsne,
#     787     gmm_n_components=gmm_n_components,
#     788     gmm_n_init=gmm_n_init,
#     789     gmm_random_state=gmm_random_state,
#     790     gmm_covariance_type=gmm_covariance_type,
#     791     reg_covar=reg_covar,
#     792     escalar_antes_tsne=escalar_antes_tsne,
#     793     escalar_tsne_para_gmm=escalar_tsne_para_gmm,
#     794     salvar_parcial=True,
#     795     arquivo_parcial=arquivo_parcial
#     796 )
#
# Cell In[3], line 463, in gerar_grid_tsne_1d_scores_resumo(arquivo_dados, arquivo_saida, pasta_saida, perplexidades, random_state, init, max_iter, learning_rate, n_jobs_tsne, features_tsne, target_name, gmm_n_components, gmm_n_init, gmm_random_state, gmm_covariance_type, reg_covar, escalar_antes_tsne, escalar_tsne_para_gmm, verbose_tsne, method_tsne, angle_tsne, salvar_parcial, arquivo_parcial)
#     447 # ====================================================
#     448 # t-SNE 1D
#     449 # ====================================================
#     451 tsne = criar_tsne_compat(
#     452     perplexity=perplexity,
#     453     random_state=random_state,
#    (...)    460     angle=angle_tsne
#     461 )
# --> 463 X_tsne = tsne.fit_transform(X_tsne_input)
#     465 n_iter_real = getattr(tsne, "n_iter_", np.nan)
#     467 # Garantir formato 2D para GMM: (n_amostras, 1)
#
# File c:\Users\Vitor Craveiro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\Vitor Craveiro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Vitor Craveiro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\manifold\_t_sne.py:1144, in TSNE.fit_transform(self, X, y)
#    1123 """Fit X into an embedded space and return that transformed output.
#    1124
#    1125 Parameters
#    (...)   1141     Embedding of the training data in low-dimensional space.
#    1142 """
#    1143 self._check_params_vs_input(X)
# -> 1144 embedding = self._fit(X)
#    1145 self.embedding_ = embedding
#    1146 return self.embedding_
#
# File c:\Users\Vitor Craveiro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\manifold\_t_sne.py:1005, in TSNE._fit(self, X, skip_num_points)
#    1002     distances_nn.data **= 2
#    1004     # compute the joint probability distribution for the input space
# -> 1005     P = _joint_probabilities_nn(distances_nn, self.perplexity, self.verbose)
#    1007 if isinstance(self.init, np.ndarray):
#    1008     X_embedded = self.init
#
# File c:\Users\Vitor Craveiro\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\manifold\_t_sne.py:115, in _joint_probabilities_nn(distances, desired_perplexity, verbose)
#     110 # Symmetrize the joint probability distribution using sparse operations
#     111 P = csr_matrix(
#     112     (conditional_P.ravel(), distances.indices, distances.indptr),
#     113     shape=(n_samples, n_samples),
#     114 )
# --> 115 P = P + P.T
#     117 # Normalize the joint probability distribution
#     118 sum_P = np.maximum(P.sum(), MACHINE_EPSILON)
#
# File c:\Users\Vitor Craveiro\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\sparse\_base.py:559, in _spbase.__add__(self, other)
#     557     if other.shape != self.shape:
#     558         raise ValueError("inconsistent shapes")
# --> 559     return self._add_sparse(other)
#     560 elif isdense(other):
#     561     other = np.broadcast_to(other, self.shape)
#
# File c:\Users\Vitor Craveiro\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\sparse\_compressed.py:386, in _cs_matrix._add_sparse(self, other)
#     385 def _add_sparse(self, other):
# --> 386     return self._binopt(other, '_plus_')
#
# File c:\Users\Vitor Craveiro\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\sparse\_compressed.py:1370, in _cs_matrix._binopt(self, other, op)
#    1368     data = np.empty(maxnnz, dtype=np.bool_)
#    1369 else:
# -> 1370     data = np.empty(maxnnz, dtype=upcast(self.dtype, other.dtype))
#    1372 M, N = self._shape_as_2d
#    1373 fn(M, N,
#    1374    np.asarray(self.indptr, dtype=idx_dtype),
#    1375    np.asarray(self.indices, dtype=idx_dtype),
#    (...)   1379    other.data,
#    1380    indptr, indices, data)
#
# MemoryError: Unable to allocate 3.81 GiB for an array with shape (511274252,) and data type float64
